# %%
import pandas as pd
import numpy as np

# %%
analytics_assessment = pd.read_excel("data/Analytics Assessment Report 2024-07-01 2024-07-31.xlsx")
#analytics_assessment.head()

# %%
def duration_to_seconds(input):
    if input == 0:
        return 0
    else:
        h, m, s = input.split()
        return int(h[:-1]) * 3600 + int(m[:-1])*60 + int(s[:-1])

analytics_assessment["duration in seconds"] = analytics_assessment["Duration (exact)"].apply(duration_to_seconds)
# analytics_assessment.head()

# %%
patients_by_duration = analytics_assessment.groupby(by=["Patient Id", "Enrolled Care Program"])["duration in seconds"].sum().reset_index()
merged_df = pd.merge(patients_by_duration, 
                     analytics_assessment[['Patient Id', 'Pharmacy Name', 'POD', 'User Name (First then Last)']].drop_duplicates(), 
                     on="Patient Id", 
                     how="left")
merged_df.head()
# Out:
#    Patient Id Enrolled Care Program  duration in seconds Pharmacy Name  \
# 0      2583.0                   CCM                 2400         iVira
# 1      2583.0                   CCM                 2400         iVira
# 2      2583.0                   CCM                 2400         iVira
# 3      2612.0                   CCM                 3911         iVira
# 4      2612.0                   PCM                   96         iVira
#
#            POD User Name (First then Last)
# 0          NaN             Francis Fuentes
# 1  Milford Pod              Michelle Mazry
# 2     Alex Pod              Michelle Mazry
# 3     Alex Pod                   Jay Patel
# 4     Alex Pod                   Jay Patel

# %%
# this will calculate revenue per minute left 
# args: duration (in seconds)
# output: ["revenue per minute"], ["remaining minutes"] - How much revenue you can gain per minute of work and how many minutes you need to work to achieve next price target
def revenue_per_minute(program, duration):
    if program == "RPM":
        if duration >= 4800: # this is the maxed out case
            return [0, 0, 0, 0]
        billing_bracket = duration // 1200
        time_to_billable = 1200 - (duration % 1200)
        percent_billed = (duration % 1200) / 1200 
        if billing_bracket >= 1: # Billable periods after the first period. Billing code: 99458
            dollars_per_minutes = 40.19 / (time_to_billable/60)
        else: # this is the first billable period. Code: 99457
            dollars_per_minutes = 40.19 / (time_to_billable/60)
        return [dollars_per_minutes, time_to_billable/60, time_to_billable, percent_billed]

    elif program == "PCM":
        if duration >= 5400: # this is the maxed out case
            return [0, 0]
        billing_bracket = duration // 1800
        time_to_billable = 1800 - (duration % 1800)
        percent_billed = (duration % 1800) / 1800 
        if billing_bracket >= 1: # Billable periods after the first period. Billing code: 99458
            dollars_per_minutes = 53.47 / (time_to_billable/60)
        else: # this is the first billable period. Code: 99457
            dollars_per_minutes = 78.60 / (time_to_billable/60)
        return [dollars_per_minutes, time_to_billable/60, time_to_billable, percent_billed]

    elif program == "CCM":
        if (duration/60) >= 61:
            billing_bracket = duration // 1800
            time_to_billable = 1800 - (duration % 1800)
            percent_billed = (duration % 1800) / 1800 
            if billing_bracket >= 1:
                dollars_per_minutes = 72.12 / (time_to_billable/60)
            else:
                dollars_per_minutes = 133.93 / (time_to_billable/60)
            return [dollars_per_minutes, time_to_billable/60, time_to_billable, percent_billed]
        else:
            billing_bracket = duration // 1200
            time_to_billable = 1200 - (duration % 1200)
            percent_billed = (duration % 1200) / 1200 
            if billing_bracket >= 1:
                dollars_per_minutes = 47.88 / (time_to_billable/60)
            else:
                dollars_per_minutes = 62.55 / (time_to_billable/60)
            return [dollars_per_minutes, time_to_billable/60, time_to_billable, percent_billed]
    else:
        return [0,0, 0, 0]



patients_by_duration[["revenue per minute", "remaining minutes", "time to billable", "percent billed"]] = patients_by_duration.apply(lambda x: revenue_per_minute(x["Enrolled Care Program"], x["duration in seconds"]), axis=1, result_type="expand")
patients_by_duration.sort_values(by="revenue per minute", ascending=False, inplace=True)
patients_by_duration.head(15)
# Out:
#       Patient Id Enrolled Care Program  duration in seconds  \
# 3419     21065.0                   CCM                 2220
# 3579     60786.0                   PCM                 1500
# 2560      7411.0                   PCM                 1500
# 1955      6397.0                   RPM                 1020
# 3427     22324.0                   CCM                  900
# 1277      5620.0                   CCM                  900
# 2869      8028.0                   CCM                  900
# 1287      5628.0                   CCM                  900
# 632       4486.0                   CCM                  900
# 1925      6367.0                   CCM                  900
# 3409     21057.0                   CCM                  900
# 1304      5649.0                   CCM                  900
# 1316      5673.0                   CCM                  900
# 3400     21051.0                   CCM                  900
# 463       3971.0                   CCM                  900
#
#       revenue per minute  remaining minutes  time to billable  percent billed
# 3419           15.960000                3.0             180.0        0.850000
# 3579           15.720000                5.0             300.0        0.833333
# 2560           15.720000                5.0             300.0        0.833333
# 1955           13.396667                3.0             180.0        0.850000
# 3427           12.510000                5.0             300.0        0.750000
# 1277           12.510000                5.0             300.0        0.750000
# 2869           12.510000                5.0             300.0        0.750000
# 1287           12.510000                5.0             300.0        0.750000
# 632            12.510000                5.0             300.0        0.750000
# 1925           12.510000                5.0             300.0        0.750000
# 3409           12.510000                5.0             300.0        0.750000
# 1304           12.510000                5.0             300.0        0.750000
# 1316           12.510000                5.0             300.0        0.750000
# 3400           12.510000                5.0             300.0        0.750000
# 463            12.510000                5.0             300.0        0.750000

# %% [markdown]
# ### I want to see how many patients each provider, pod, and User Name has the highest # of people with patients billed > 50%

# %%
merged_df = pd.merge(patients_by_duration, 
                     analytics_assessment[['Patient Id', 'Pharmacy Name', 'POD', 'User Name (First then Last)']].drop_duplicates(), 
                     on="Patient Id", 
                     how="left") # merge in the Pharmacy Name, POD, and User Name

filtered_df = merged_df[merged_df['percent billed'] > 0.5]

# %%
user_patient_billed_over_50_perc = filtered_df.groupby(['User Name (First then Last)'])['Patient Id'].nunique().reset_index()

# Rename the column to indicate it's a count of patients
user_patient_billed_over_50_perc.rename(columns={'Patient Id': 'patient_count'}, inplace=True)
user_patient_billed_over_50_perc.sort_values(by=["patient_count"], inplace=True, ascending=False)

user_patient_billed_over_50_perc.head()
# Out:
#    User Name (First then Last)  patient_count
# 14               Karla Miranda             83
# 15                Mariel Parra             65
# 3             Annegelie Rivera             49
# 16           MaryJane DelaCruz             45
# 7              Danielle Arcete             26

# %%
pod_patient_billed_over_50_perc = filtered_df.groupby(['POD'])['Patient Id'].nunique().reset_index()

# Rename the column to indicate it's a count of patients
pod_patient_billed_over_50_perc.rename(columns={'Patient Id': 'patient_count'}, inplace=True)
pod_patient_billed_over_50_perc.sort_values(by=["patient_count"], inplace=True, ascending=False)

pod_patient_billed_over_50_perc.head()
# Out:
#             POD  patient_count
# 4    Morgen Pod            141
# 1     Gabby Pod             98
# 5   Natasha Pod             26
# 0      Alex Pod             22
# 6  Wellness POD              6

# %%
pharmacy_patient_billed_over_50_perc = filtered_df.groupby(['Pharmacy Name'])['Patient Id'].nunique().reset_index()

# Rename the column to indicate it's a count of patients
pharmacy_patient_billed_over_50_perc.rename(columns={'Patient Id': 'patient_count'}, inplace=True)
pharmacy_patient_billed_over_50_perc.sort_values(by=["patient_count"], inplace=True, ascending=False)

pharmacy_patient_billed_over_50_perc.head()
# Out:
#   Pharmacy Name  patient_count
# 0         iVira            369

# %% [markdown]
# # Employees hours as a share of their pods

# %%
df = pd.read_excel("data/Analytics Assessment Report 2024-07-01 2024-07-31.xlsx")
df.rename(columns={"User Name (First then Last)":"Employee"}, inplace=True)
df["duration in seconds"] = df["Duration (exact)"].apply(duration_to_seconds)
df.drop(["EHR#", "FirstName", "LastName", "Birth Date", "Assessment ID", "Tertiary Plan Name"], axis=1, inplace=True)
df.head()
# Out:
#    Patient Id                              Primary Plan Name  \
# 0      2583.0            Highmark Blue Cross And Blue Shield
# 1      2583.0            Highmark Blue Cross And Blue Shield
# 2      2583.0            Highmark Blue Cross And Blue Shield
# 3      2612.0   test planHighmark Blue Cross And Blue Shield
# 4      2612.0   test planHighmark Blue Cross And Blue Shield
#
#             Secondary Plan Name                 Practice  \
# 0                           NaN           Ivira Pharmacy
# 1                           NaN           Ivira Pharmacy
# 2                           NaN           Ivira Pharmacy
# 3  TEST Highmark Health Options  Highmark Health Options
# 4  TEST Highmark Health Options  Highmark Health Options
#
#   Provider from Practice Pharmacy Name         Employee          POD  \
# 0         Mayda Melendez         iVira  Francis Fuentes          NaN
# 1         Mayda Melendez         iVira   Michelle Mazry  Milford Pod
# 2         Mayda Melendez         iVira   Michelle Mazry     Alex Pod
# 3         Mayda Melendez         iVira        Jay Patel     Alex Pod
# 4         Mayda Melendez         iVira        Jay Patel     Alex Pod
#
#      User Type Duration (exact) Enrolled Care Program  \
# 0  caremanager                0                   CCM
# 1  caremanager       0h 20m 00s                   CCM
# 2  caremanager       0h 20m 00s                   CCM
# 3   pharmacist       0h 00m 49s                   PCM
# 4   pharmacist       0h 00m 38s                   CCM
#
#                          Call Type Selected Assessment Time Date  \
# 0                      Administrative Tasks           07-01-2024
# 1                      Administrative Tasks           07-08-2024
# 2                      Administrative Tasks           07-08-2024
# 3                GH Deficiency Care Journey           07-29-2024
# 4  Acute Myocardial Infarction Care Journey           07-03-2024
#
#    duration in seconds
# 0                    0
# 1                 1200
# 2                 1200
# 3                   49
# 4                   38

# %%
#print(df[df["Employee"] == "Gabriella McGinley"].groupby(by=["POD"])["duration in seconds"].sum())
gab_mcginley_df = df[df["Employee"] == "Michelle Mazry"]#[["Patient Id", "Duration (exact)"]]
gab_mcginley_df.head(20)
# Out:
#      Patient Id                    Primary Plan Name  \
# 1        2583.0  Highmark Blue Cross And Blue Shield
# 2        2583.0  Highmark Blue Cross And Blue Shield
# 15       2616.0  Highmark Blue Cross And Blue Shield
# 16       2616.0  Highmark Blue Cross And Blue Shield
# 68       2676.0                          Amerihealth
# 69       2676.0                          Amerihealth
# 164      2805.0                          Amerihealth
# 166      2805.0                          Amerihealth
# 350      3057.0                                  NaN
# 351      3057.0                                  NaN
# 371      3080.0  Highmark Blue Cross And Blue Shield
# 372      3080.0  Highmark Blue Cross And Blue Shield
# 468      3597.0                 Wellcare Health Plan
# 469      3597.0                 Wellcare Health Plan
# 470      3798.0                          Amerihealth
# 471      3798.0                          Amerihealth
# 474      3811.0                          Amerihealth
# 475      3811.0                          Amerihealth
# 476      3812.0  Highmark Blue Cross And Blue Shield
# 477      3812.0  Highmark Blue Cross And Blue Shield
#
#                       Secondary Plan Name        Practice  \
# 1                                     NaN  Ivira Pharmacy
# 2                                     NaN  Ivira Pharmacy
# 15                                    NaN  Ivira Pharmacy
# 16                                    NaN  Ivira Pharmacy
# 68                                    NaN  Ivira Pharmacy
# 69                                    NaN  Ivira Pharmacy
# 164                                   NaN  Ivira Pharmacy
# 166                                   NaN  Ivira Pharmacy
# 350                                   NaN  Ivira Pharmacy
# 351                                   NaN  Ivira Pharmacy
# 371                                   NaN  Ivira Pharmacy
# 372                                   NaN  Ivira Pharmacy
# 468   Highmark Blue Cross And Blue Shield  Ivira Pharmacy
# 469   Highmark Blue Cross And Blue Shield  Ivira Pharmacy
# 470                                        Ivira Pharmacy
# 471                                        Ivira Pharmacy
# 474                                   NaN  Ivira Pharmacy
# 475                                   NaN  Ivira Pharmacy
# 476                                   NaN  Ivira Pharmacy
# 477                                   NaN  Ivira Pharmacy
#
#     Provider from Practice Pharmacy Name        Employee          POD  \
# 1           Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 2           Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 15          Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 16          Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 68          Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 69          Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 164         Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 166         Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 350         Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 351         Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 371         Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 372         Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 468         Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 469         Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 470         Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 471         Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 474         Mayda Melendez         iVira  Michelle Mazry     Alex Pod
# 475         Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 476         Mayda Melendez         iVira  Michelle Mazry  Milford Pod
# 477         Mayda Melendez         iVira  Michelle Mazry     Alex Pod
#
#        User Type Duration (exact) Enrolled Care Program    Call Type Selected  \
# 1    caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 2    caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 15   caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 16   caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 68   caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 69   caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 164  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 166  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 350  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 351  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 371  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 372  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 468  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 469  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 470  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 471  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 474  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 475  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 476  caremanager       0h 20m 00s                   CCM  Administrative Tasks
# 477  caremanager       0h 20m 00s                   CCM  Administrative Tasks
#
#     Assessment Time Date  duration in seconds
# 1             07-08-2024                 1200
# 2             07-08-2024                 1200
# 15            07-09-2024                 1200
# 16            07-09-2024                 1200
# 68            07-15-2024                 1200
# 69            07-15-2024                 1200
# 164           07-19-2024                 1200
# 166           07-19-2024                 1200
# 350           07-22-2024                 1200
# 351           07-22-2024                 1200
# 371           07-01-2024                 1200
# 372           07-01-2024                 1200
# 468           07-19-2024                 1200
# 469           07-19-2024                 1200
# 470           07-22-2024                 1200
# 471           07-22-2024                 1200
# 474           07-18-2024                 1200
# 475           07-18-2024                 1200
# 476           07-22-2024                 1200
# 477           07-22-2024                 1200

# %%
pod_total_seconds_billed = df.groupby(by=["POD"])["duration in seconds"].sum().reset_index()
pod_total_seconds_billed.head()
# Out:
#            POD  duration in seconds
# 0     Alex Pod               242158
# 1    Gabby Pod               271500
# 2   Market Pod                68640
# 3  Milford Pod               210300
# 4   Morgen Pod               967560

# %%
total_billables_df = {}

def calculate_total_billables_per_pod(employee, pod, duration):
    key = (employee, pod)
    if key in total_billables_df:
        total_billables_df[key] += int(duration)
    else:
        total_billables_df[key] = int(duration)


for i in range(len(df)):
    calculate_total_billables_per_pod(df.iloc[i]["Employee"], df.iloc[i]["POD"], df.iloc[i]["duration in seconds"])

print(total_billables_df)
# Out:
# {('Francis Fuentes', nan): 42600, ('Michelle Mazry', 'Milford Pod'): 177000, ('Michelle Mazry', 'Alex Pod'): 177000, ('Jay Patel', 'Alex Pod'): 5158, ('Euro Montero', 'Gabby Pod'): 90900, ('Natasha Bidadi', 'Natasha Pod'): 392664, ('Danielle Arcete', nan): 218160, ('Mariel Parra', 'Gabby Pod'): 153900, ('Paula Dayandayan', nan): 212100, ('Gabriella McGinley', 'Alex Pod'): 26700, ('Gabriella McGinley', 'Gabby Pod'): 26700, ('Gabriella McGinley', 'Morgen Pod'): 26700, ('AnaCristina Kolster', nan): 147480, ('Brooke Bunting', nan): 58200, ('Zainab Haque', 'Wellness POD'): 119400, ('Diana Muslemani', 'Natasha Pod'): 184500, ('Alycia Lewis', nan): 99900, ('Chelsea Myer', 'Wellness POD'): 97200, ('Alexis Veres', nan): 36300, ('Annegelie Rivera', nan): 209112, ('MaryJane DelaCruz', nan): 358200, ('Victor Guerra', nan): 225900, ('Alex PerryFerrari', 'Milford Pod'): 33300, ('Alex PerryFerrari', 'Alex Pod'): 33300, ('Crystal Lam', nan): 43200, ('Karla Miranda', 'Morgen Pod'): 338110, ('Dina Mourad', 'Market Pod'): 68640, ('Vanessa Batallones', nan): 71462, ('Sarah Mohammed', 'Morgen Pod'): 306000, ('Morgen Sitzler', 'Morgen Pod'): 296750, ('Ruby JaleLusuegro', nan): 557, ('Jigar Patel', nan): 14400, ('Tamara Lewis', 'Tamara POD'): 300}

# %%
print(total_billables_df)
result_df = pd.DataFrame([
    {'Employee': emp_dept[0], 'POD': emp_dept[1], 'SecondsWorked': hours}
    for emp_dept, hours in total_billables_df.items()
]).reset_index()
print(result_df)
# Out:
# {('Francis Fuentes', nan): 42600, ('Michelle Mazry', 'Milford Pod'): 177000, ('Michelle Mazry', 'Alex Pod'): 177000, ('Jay Patel', 'Alex Pod'): 5158, ('Euro Montero', 'Gabby Pod'): 90900, ('Natasha Bidadi', 'Natasha Pod'): 392664, ('Danielle Arcete', nan): 218160, ('Mariel Parra', 'Gabby Pod'): 153900, ('Paula Dayandayan', nan): 212100, ('Gabriella McGinley', 'Alex Pod'): 26700, ('Gabriella McGinley', 'Gabby Pod'): 26700, ('Gabriella McGinley', 'Morgen Pod'): 26700, ('AnaCristina Kolster', nan): 147480, ('Brooke Bunting', nan): 58200, ('Zainab Haque', 'Wellness POD'): 119400, ('Diana Muslemani', 'Natasha Pod'): 184500, ('Alycia Lewis', nan): 99900, ('Chelsea Myer', 'Wellness POD'): 97200, ('Alexis Veres', nan): 36300, ('Annegelie Rivera', nan): 209112, ('MaryJane DelaCruz', nan): 358200, ('Victor Guerra', nan): 225900, ('Alex PerryFerrari', 'Milford Pod'): 33300, ('Alex PerryFerrari', 'Alex Pod'): 33300, ('Crystal Lam', nan): 43200, ('Karla Miranda', 'Morgen Pod'): 338110, ('Dina Mourad', 'Market Pod'): 68640, ('Vanessa Batallones', nan): 71462, ('Sarah Mohammed', 'Morgen Pod'): 306000, ('Morgen Sitzler', 'Morgen Pod'): 296750, ('Ruby JaleLusuegro', nan): 557, ('Jigar Patel', nan): 14400, ('Tamara Lewis', 'Tamara POD'): 300}
#     index             Employee           POD  SecondsWorked
# 0       0      Francis Fuentes           NaN          42600
# 1       1       Michelle Mazry   Milford Pod         177000
# 2       2       Michelle Mazry      Alex Pod         177000
# 3       3            Jay Patel      Alex Pod           5158
# 4       4         Euro Montero     Gabby Pod          90900
# 5       5       Natasha Bidadi   Natasha Pod         392664
# 6       6      Danielle Arcete           NaN         218160
# 7       7         Mariel Parra     Gabby Pod         153900
# 8       8     Paula Dayandayan           NaN         212100
# 9       9   Gabriella McGinley      Alex Pod          26700
# 10     10   Gabriella McGinley     Gabby Pod          26700
# 11     11   Gabriella McGinley    Morgen Pod          26700
# 12     12  AnaCristina Kolster           NaN         147480
# 13     13       Brooke Bunting           NaN          58200
# 14     14         Zainab Haque  Wellness POD         119400
# 15     15      Diana Muslemani   Natasha Pod         184500
# 16     16         Alycia Lewis           NaN          99900
# 17     17         Chelsea Myer  Wellness POD          97200
# 18     18         Alexis Veres           NaN          36300
# 19     19     Annegelie Rivera           NaN         209112
# 20     20    MaryJane DelaCruz           NaN         358200
# 21     21        Victor Guerra           NaN         225900
# 22     22    Alex PerryFerrari   Milford Pod          33300
# 23     23    Alex PerryFerrari      Alex Pod          33300
# 24     24          Crystal Lam           NaN          43200
# 25     25        Karla Miranda    Morgen Pod         338110
# 26     26          Dina Mourad    Market Pod          68640
# 27     27   Vanessa Batallones           NaN          71462
# 28     28       Sarah Mohammed    Morgen Pod         306000
# 29     29       Morgen Sitzler    Morgen Pod         296750
# 30     30    Ruby JaleLusuegro           NaN            557
# 31     31          Jigar Patel           NaN          14400
# 32     32         Tamara Lewis    Tamara POD            300

# %%
df.head()
# Out:
#    Patient Id                              Primary Plan Name  \
# 0      2583.0            Highmark Blue Cross And Blue Shield
# 1      2583.0            Highmark Blue Cross And Blue Shield
# 2      2583.0            Highmark Blue Cross And Blue Shield
# 3      2612.0   test planHighmark Blue Cross And Blue Shield
# 4      2612.0   test planHighmark Blue Cross And Blue Shield
#
#             Secondary Plan Name                 Practice  \
# 0                           NaN           Ivira Pharmacy
# 1                           NaN           Ivira Pharmacy
# 2                           NaN           Ivira Pharmacy
# 3  TEST Highmark Health Options  Highmark Health Options
# 4  TEST Highmark Health Options  Highmark Health Options
#
#   Provider from Practice Pharmacy Name         Employee          POD  \
# 0         Mayda Melendez         iVira  Francis Fuentes          NaN
# 1         Mayda Melendez         iVira   Michelle Mazry  Milford Pod
# 2         Mayda Melendez         iVira   Michelle Mazry     Alex Pod
# 3         Mayda Melendez         iVira        Jay Patel     Alex Pod
# 4         Mayda Melendez         iVira        Jay Patel     Alex Pod
#
#      User Type Duration (exact) Enrolled Care Program  \
# 0  caremanager                0                   CCM
# 1  caremanager       0h 20m 00s                   CCM
# 2  caremanager       0h 20m 00s                   CCM
# 3   pharmacist       0h 00m 49s                   PCM
# 4   pharmacist       0h 00m 38s                   CCM
#
#                          Call Type Selected Assessment Time Date  \
# 0                      Administrative Tasks           07-01-2024
# 1                      Administrative Tasks           07-08-2024
# 2                      Administrative Tasks           07-08-2024
# 3                GH Deficiency Care Journey           07-29-2024
# 4  Acute Myocardial Infarction Care Journey           07-03-2024
#
#    duration in seconds
# 0                    0
# 1                 1200
# 2                 1200
# 3                   49
# 4                   38

# %%
billed_hours_by_care_type = df.groupby(by=["Call Type Selected"])["duration in seconds"].sum().reset_index()
billed_hours_by_care_type["duration in minutes"] = round(billed_hours_by_care_type["duration in seconds"] / 60, 2)
billed_hours_by_care_type.head()
# Out:
#                                   Call Type Selected  duration in seconds  \
# 0                                           AMR Call                 3300
# 1  AMR Call, Atrial Fibrillation and Atrial Flutt...                   29
# 2           Acute Myocardial Infarction Care Journey                 3855
# 3                               Administrative Tasks              1146932
# 4      Administrative Tasks, Depression Care Journey                12600
#
#    duration in minutes
# 0            55.000000
# 1             0.483333
# 2            64.250000
# 3         19115.533333
# 4           210.000000
